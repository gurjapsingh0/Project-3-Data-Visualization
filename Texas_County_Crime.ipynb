# %%
#Import all libraries to get started
import pandas as pd
import numpy as np
import chart_studio.plotly as py

import cufflinks as cf
import seaborn as sns
import plotly.express as px
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode,plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
#import in the excel file that will form our database(from dps.texas.gov)
df = pd.read_excel(r"C:\Users\gurja\OneDrive\Project-3-Data-Visualization\Crime Data\2022_Texas_County_Crime.xlsx", 
                  engine = 'openpyxl')

df.head()
# Out:
#             County  Population  Murder  Rape  Robbery  Assault  Burglary  \
# 0  ANDERSON COUNTY     20230.0     1.0  32.0      7.0     99.0     124.0
# 1   ANDREWS COUNTY     18380.0     1.0   5.0      0.0     60.0      32.0
# 2  ANGELINA COUNTY     82128.0     6.0  78.0     26.0    216.0     410.0
# 3   ARANSAS COUNTY     31050.0     3.0  19.0      9.0    134.0     151.0
# 4    ARCHER COUNTY      1593.0     0.0   1.0      0.0      0.0       4.0
#
#    Larceny  Auto Theft   Total  Unnamed: 10
# 0    356.0        32.0   651.0          NaN
# 1    192.0        22.0   312.0          NaN
# 2   1296.0       187.0  2219.0          NaN
# 3    523.0        54.0   893.0          NaN
# 4      2.0         2.0     9.0          NaN

# %%
df = df.drop(columns=['Unnamed: 10'])
df
# Out:
#               County  Population  Murder  Rape  Robbery  Assault  Burglary  \
# 0    ANDERSON COUNTY     20230.0     1.0  32.0      7.0     99.0     124.0
# 1     ANDREWS COUNTY     18380.0     1.0   5.0      0.0     60.0      32.0
# 2    ANGELINA COUNTY     82128.0     6.0  78.0     26.0    216.0     410.0
# 3     ARANSAS COUNTY     31050.0     3.0  19.0      9.0    134.0     151.0
# 4      ARCHER COUNTY      1593.0     0.0   1.0      0.0      0.0       4.0
# ..               ...         ...     ...   ...      ...      ...       ...
# 249      WOOD COUNTY     47838.0     1.0  12.0     11.0     64.0     108.0
# 250    YOAKUM COUNTY      7591.0     0.0   0.0      0.0     17.0      11.0
# 251     YOUNG COUNTY     18225.0     0.0   5.0      2.0     24.0      23.0
# 252    ZAPATA COUNTY     14016.0     0.0   0.0      0.0      5.0      12.0
# 253    ZAVALA COUNTY      3222.0     0.0   2.0      0.0     12.0       9.0
#
#      Larceny  Auto Theft   Total
# 0      356.0        32.0   651.0
# ...

# %%
#looking at 1/10 counties that had no data
row_217 = df.iloc[216]
print(row_217)
# Out:
# County        STONEWALL COUNTY
# Population                 NaN
# Murder                     NaN
# Rape                       NaN
# Robbery                    NaN
# Assault                    NaN
# Burglary                   NaN
# Larceny                    NaN
# Auto Theft                 NaN
# Total                      NaN
# Name: 216, dtype: object

# %%
#Assuming those 10 counties had no crime reports we will fill in the values as zero
df = df.fillna(0)

# %%
#I want to create a filter for population size, that then shows the counties with that population constraint to pick from
